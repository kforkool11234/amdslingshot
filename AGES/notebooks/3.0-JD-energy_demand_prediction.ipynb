# %%
import os
import joblib

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
PROCESSED_DATA ='../data/processed/'


TEST_DATA = '../data/processed/test/'
TRAIN_DATA = '../data/processed/train/'


REPORT = '../reports/figures/'


MODEL_PATH = '../models/'

# %%
SCALER = MinMaxScaler(feature_range=(0, 1))

# %%
TRAIN_DATA_PATH = os.path.join(TRAIN_DATA, 'dataset.csv')
TEST_DATA_PATH = os.path.join(TEST_DATA, 'dataset.csv')

# %%
TRAINING_DATASET = pd.read_csv(TRAIN_DATA_PATH, index_col='Timestamp', parse_dates=True)

TESTING_DATASET = pd.read_csv(TEST_DATA_PATH, index_col='Timestamp', parse_dates=True)

# %%
COLUMNS = ['Power Consumption (kW)', 'Voltage (V)', 'Current (A)', 'Reactive Power (kVAR)', 'Power Factor', 'Solar Power (kW)', 'Wind Power (kW)', 'Grid Supply (kW)', 'Voltage Fluctuation (%)', 'Temperature (°C)', 'Humidity (%)', 'Electricity Price (USD/kWh)', 'Zenith Angle', 'Solar Lag (1h)', 'Solar Lag (2h)', 'Moving Avgerage', 'Rolling STD']

# %%
TRAINING_DATASET[COLUMNS] = SCALER.fit_transform(TRAINING_DATASET[COLUMNS])

# %%
TESTING_DATASET[COLUMNS] = SCALER.transform(TESTING_DATASET[COLUMNS])

# %%
SCALER_PATH = os.path.join(MODEL_PATH, 'scaler/demand.pkl')

joblib.dump(SCALER, SCALER_PATH)
